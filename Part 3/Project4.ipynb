# %%
from collections import namedtuple
import csv
from datetime import datetime

employment_filepath = 'files\\project_files\\employment.csv'
personal_filepath = 'files/project_files/personal_info.csv'
update_filepath = 'files/project_files/update_status.csv'
vehicles_filepath = 'files/project_files/vehicles.csv'

def employment_csv_reader(filepath):
    with open(filepath) as f:
        reader = csv.reader(f, delimiter=',', quotechar='"')
        Employment = namedtuple('Employment', next(reader))
        for i in reader:
            yield Employment(*i)


def personal_info_csv_reader(filepath):
    with open(filepath) as f:
        reader = csv.reader(f, delimiter=',', quotechar='"')
        Personal = namedtuple('Personal', next(reader))
        for i in reader:
            yield Personal(*i)


def update_status_csv_reader(filepath):
    with open(filepath) as f:
        reader = csv.reader(f, delimiter=',', quotechar='"')
        Update_status = namedtuple('Update_status', next(reader))
        for i in reader:
            i[1] = datetime.strptime(i[1], "%Y-%m-%dT%H:%M:%SZ").date()
            i[2] = datetime.strptime(i[2], "%Y-%m-%dT%H:%M:%SZ").date()
            yield Update_status(*i)


def vehicles_csv_reader(filepath):
    with open(filepath) as f:
        reader = csv.reader(f, delimiter=',', quotechar='"')
        Vehicle = namedtuple('Vehicle', next(reader))
        for i in reader:
            i[3] = int(i[3])
            yield Vehicle(*i)


emp_reader = employment_csv_reader(employment_filepath)
personal_reader = personal_info_csv_reader(personal_filepath)
update_reader = update_status_csv_reader(update_filepath)
vehicle_reader = vehicles_csv_reader(vehicles_filepath)

# %%
next(emp_reader)._fields
# Out:
# ('employer', 'department', 'employee_id', 'ssn')

# %%
import glob
import os
from collections import namedtuple
import csv
from datetime import datetime, date

employment_filepath = 'files\\project_files\\employment.csv'
personal_filepath = 'files/project_files/personal_info.csv'
update_filepath = 'files/project_files/update_status.csv'
vehicles_filepath = 'files/project_files/vehicles.csv'

filepaths = (employment_filepath, personal_filepath, update_filepath, vehicles_filepath)
readers = (employment_csv_reader, personal_info_csv_reader, update_status_csv_reader, vehicles_csv_reader)

def comb_csv_reader():
    def employment_csv_reader(filepath):
        with open(filepath) as f:
            reader = csv.reader(f, delimiter=',', quotechar='"')
            yield next(reader)
            for i in reader:
                yield i


    def personal_info_csv_reader(filepath):
        with open(filepath) as f:
            reader = csv.reader(f, delimiter=',', quotechar='"')
            yield next(reader)[1:]
            for i in reader:
                yield i[1:]

    def update_status_csv_reader(filepath):
        with open(filepath) as f:
            reader = csv.reader(f, delimiter=',', quotechar='"')
            yield next(reader)[1:]
            for i in reader:
                i[1] = datetime.strptime(i[1], "%Y-%m-%dT%H:%M:%SZ").date()
                i[2] = datetime.strptime(i[2], "%Y-%m-%dT%H:%M:%SZ").date()
                yield i[1:]

    def vehicles_csv_reader(filepath):
        with open(filepath) as f:
            reader = csv.reader(f, delimiter=',', quotechar='"')
            yield next(reader)[1:]
            for i in reader:
                i[3] = int(i[3])
                yield i[1:]

    reader_dict = {f'{reader.__name__}': reader(filepath) for reader, filepath in zip(readers, filepaths)}
    colnames = []
    for reader in reader_dict.values():
        colnames += next(reader)

    Combined = namedtuple('Combined', colnames)
    print(colnames)
    done = False
    while not done:
        comb_vals = []
        try:
            for reader in reader_dict.values():
                comb_vals += next(reader)
        except StopIteration:
            done = True
            break
        if not comb_vals[8] < date(2017, 3, 1):
            combined_data = Combined(*comb_vals)
            yield combined_data

results = []
combo_reader = comb_csv_reader()
for entry in combo_reader:
    results.append(entry)

# %%
import glob
import os
from collections import namedtuple
import csv
from datetime import datetime, date

employment_filepath = 'files\\project_files\\employment.csv'
personal_filepath = 'files/project_files/personal_info.csv'
update_filepath = 'files/project_files/update_status.csv'
vehicles_filepath = 'files/project_files/vehicles.csv'

filepaths = (employment_filepath, personal_filepath, update_filepath, vehicles_filepath)
readers = (employment_csv_reader, personal_info_csv_reader, update_status_csv_reader, vehicles_csv_reader)

def comb_csv_reader():
    def employment_csv_reader(filepath):
        with open(filepath) as f:
            reader = csv.reader(f, delimiter=',', quotechar='"')
            yield next(reader)
            for i in reader:
                yield i


    def personal_info_csv_reader(filepath):
        with open(filepath) as f:
            reader = csv.reader(f, delimiter=',', quotechar='"')
            yield next(reader)[1:]
            for i in reader:
                yield i[1:]

    def update_status_csv_reader(filepath):
        with open(filepath) as f:
            reader = csv.reader(f, delimiter=',', quotechar='"')
            yield next(reader)[1:]
            for i in reader:
                i[1] = datetime.strptime(i[1], "%Y-%m-%dT%H:%M:%SZ").date()
                i[2] = datetime.strptime(i[2], "%Y-%m-%dT%H:%M:%SZ").date()
                yield i[1:]

    def vehicles_csv_reader(filepath):
        with open(filepath) as f:
            reader = csv.reader(f, delimiter=',', quotechar='"')
            yield next(reader)[1:]
            for i in reader:
                i[3] = int(i[3])
                yield i[1:]

    reader_dict = {f'{reader.__name__}': reader(filepath) for reader, filepath in zip(readers, filepaths)}
    colnames = []
    for reader in reader_dict.values():
        colnames += next(reader)

    Combined = namedtuple('Combined', colnames)
    print(colnames)
    done = False
    while not done:
        comb_vals = []
        try:
            for reader in reader_dict.values():
                comb_vals += next(reader)
        except StopIteration:
            done = True
            break
        if not comb_vals[8] < date(2017, 3, 1):
            combined_data = Combined(*comb_vals)
            yield combined_data

results = []
combo_reader = comb_csv_reader()
for entry in combo_reader:
    results.append(entry)
# Out:
# ['employer', 'department', 'employee_id', 'ssn', 'first_name', 'last_name', 'gender', 'language', 'last_updated', 'created', 'vehicle_make', 'vehicle_model', 'model_year']

# %%
results
# Out:
# [Combined(employer='Stiedemann-Bailey', department='Research and Development', employee_id='29-0890771', ssn='100-53-9824', first_name='Sebastiano', last_name='Tester', gender='Male', language='Icelandic', last_updated=datetime.date(2017, 10, 7), created=datetime.date(2016, 1, 24), vehicle_make='Oldsmobile', vehicle_model='Bravada', model_year=1993),
#  Combined(employer='Connelly Group', department='Research and Development', employee_id='98-7952860', ssn='101-84-0356', first_name='Nomi', last_name='Lipprose', gender='Female', language='Yiddish', last_updated=datetime.date(2017, 10, 4), created=datetime.date(2016, 9, 21), vehicle_make='GMC', vehicle_model='Yukon', model_year=2005),
#  Combined(employer='Upton LLC', department='Marketing', employee_id='56-9817552', ssn='104-22-0928', first_name='Justinian', last_name='Kunzelmann', gender='Male', language='Dhivehi', last_updated=datetime.date(2017, 3, 28), created=datetime.date(2016, 4, 15), vehicle_make='Oldsmobile', vehicle_model='Intrigue', model_year=2000),
#  Combined(employer='Zemlak-Olson', department='Business Development', employee_id='46-2886707', ssn='104-84-7144', first_name='Claudianus', last_name='Brixey', gender='Male', language='Afrikaans', last_updated=datetime.date(2018, 2, 19), created=datetime.date(2016, 3, 15), vehicle_make='Ford', vehicle_model='Crown Victoria', model_year=2008),
#  Combined(employer='Kohler, Bradtke and Davis', department='Support', employee_id='80-0975518', ssn='105-27-5541', first_name='Federico', last_name='Aggett', gender='Male', language='Chinese', last_updated=datetime.date(2017, 7, 24), created=datetime.date(2016, 7, 23), vehicle_make='Ford', vehicle_model='Mustang', model_year=2001),
#  Combined(employer='Roberts, Torphy and Dach', department='Human Resources', employee_id='77-4895332', ssn='105-85-7486', first_name='Angelina', last_name='McAvey', gender='Female', language='Punjabi', last_updated=datetime.date(2018, 2, 14), created=datetime.date(2016, 12, 15), vehicle_make='Chrysler', vehicle_model='300', model_year=2008),
#  Combined(employer='Lind-Jast', department='Marketing', employee_id='79-6418731', ssn='105-91-5022', first_name='Moselle', last_name='Apfel', gender='Female', language='Latvian', last_updated=datetime.date(2018, 3, 24), created=datetime.date(2016, 3, 24), vehicle_make='Isuzu', vehicle_model='Hombre Space', model_year=2000),
#  Combined(employer='Bashirian-Lueilwitz', department='Engineering', employee_id='44-3328799', ssn='105-91-7777', first_name='Audi', last_name='Roach', gender='Female', language='Estonian', last_updated=datetime.date(2017, 5, 11), created=datetime.date(2016, 5, 31), vehicle_make='Chevrolet', vehicle_model='Silverado 3500', model_year=2004),
#  Combined(employer='Windler, Marks and Haley', department='Services', employee_id='54-6271885', ssn='106-35-1938', first_name='Mackenzie', last_name='Nussey', gender='Male', language='Swedish', last_updated=datetime.date(2017, 10, 21), created=datetime.date(2016, 9, 8), vehicle_make='GMC', vehicle_model='Sonoma Club', model_year=1992),
#  Combined(employer='Leffler-Hahn', department='Accounting', employee_id='31-5735282', ssn='106-36-3293', first_name='Martino', last_name='Tregoning', gender='Male', language='Tok Pisin', last_updated=datetime.date(2017, 3, 18), created=datetime.date(2016, 5, 16), vehicle_make='Volkswagen', vehicle_model='Touareg', model_year=2008),
#  Combined(employer='Lueilwitz LLC', department='Marketing', employee_id='33-9146042', ssn='110-84-3641', first_name='Amberly', last_name='Huws', gender='Female', language='Papiamento', last_updated=datetime.date(2017, 9, 4), created=datetime.date(2016, 9, 12), vehicle_make='Ford', vehicle_model='Mustang', model_year=1990),
#  Combined(employer='Davis Inc', department='Accounting', employee_id='39-0400385', ssn='111-35-1034', first_name='Giacopo', last_name='Timperley', gender='Male', language='Gagauz', last_updated=datetime.date(2017, 3, 18), created=datetime.date(2016, 8, 21), vehicle_make='Ford', vehicle_model='Fiesta', model_year=2001),
#  Combined(employer='Kunze LLC', department='Research and Development', employee_id='78-2612900', ssn='114-06-6912', first_name='Jule', last_name='Velte', gender='Male', language='Dutch', last_updated=datetime.date(2018, 2, 5), created=datetime.date(2016, 7, 15), vehicle_make='Aston Martin', vehicle_model='DBS', model_year=2011),
#  Combined(employer='Mayert, Rice and Schmitt', department='Product Management', employee_id='85-8596488', ssn='114-66-0984', first_name='Casandra', last_name='Juares', gender='Female', language='Lithuanian', last_updated=datetime.date(2017, 6, 16), created=datetime.date(2016, 5, 28), vehicle_make='Chevrolet', vehicle_model='Camaro', model_year=1998),
#  Combined(employer='Pouros LLC', department='Legal', employee_id='14-2589283', ssn='114-74-8701', first_name='Levey', last_name='Baradel', gender='Male', language='Icelandic', last_updated=datetime.date(2017, 10, 30), created=datetime.date(2016, 6, 4), vehicle_make='Mercedes-Benz', vehicle_model='CL65 AMG', model_year=2009),
#  Combined(employer='Pfannerstill Group', department='Research and Development', employee_id='43-1532437', ssn='116-10-7235', first_name='Chiquita', last_name='Danbi', gender='Female', language='Dari', last_updated=datetime.date(2017, 3, 10), created=datetime.date(2016, 10, 17), vehicle_make='Bugatti', vehicle_model='Veyron', model_year=2009),
#  Combined(employer='Ryan Group', department='Sales', employee_id='08-8274517', ssn='116-77-4915', first_name='Herold', last_name='Fearon', gender='Male', language='Italian', last_updated=datetime.date(2017, 11, 21), created=datetime.date(2016, 7, 3), vehicle_make='Buick', vehicle_model='Rainier', model_year=2004),
#  Combined(employer='Ritchie-Pagac', department='Business Development', employee_id='38-0095184', ssn='117-39-6617', first_name='Auroora', last_name='Yong', gender='Female', language='Swahili', last_updated=datetime.date(2017, 9, 1), created=datetime.date(2016, 12, 1), vehicle_make='Scion', vehicle_model='tC', model_year=2008),
#  Combined(employer='Kerluke-Dibbert', department='Services', employee_id='90-5121197', ssn='117-78-6202', first_name='Dareen', last_name='Jiggins', gender='Female', language='Polish', last_updated=datetime.date(2017, 11, 2), created=datetime.date(2016, 4, 18), vehicle_make='Rolls-Royce', vehicle_model='Phantom', model_year=2007),
#  Combined(employer='Hane-Klocko', department='Human Resources', employee_id='27-2946273', ssn='118-21-0357', first_name='Laina', last_name='Bayly', gender='Female', language='Bulgarian', last_updated=datetime.date(2017, 12, 13), created=datetime.date(2016, 10, 24), vehicle_make='GMC', vehicle_model='3500 Club Coupe', model_year=1992),
#  Combined(employer='Ernser LLC', department='Services', employee_id='07-6466085', ssn='118-95-7100', first_name='Alexi', last_name='Leglise', gender='Female', language='Lithuanian', last_updated=datetime.date(2017, 4, 25), created=datetime.date(2016, 1, 29), vehicle_make='Plymouth', vehicle_model='Laser', model_year=1993),
#  Combined(employer='Terry LLC', department='Accounting', employee_id='70-4864087', ssn='119-07-8817', first_name='Blondie', last_name='Powderham', gender='Female', language='Croatian', last_updated=datetime.date(2017, 12, 24), created=datetime.date(2016, 12, 6), vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2005),
#  Combined(employer='Rolfson, Price and Crooks', department='Business Development', employee_id='77-0255816', ssn='120-33-5535', first_name='Eugen', last_name='Shark', gender='Male', language='Dhivehi', last_updated=datetime.date(2017, 11, 11), created=datetime.date(2016, 7, 10), vehicle_make='Isuzu', vehicle_model='Trooper', model_year=1997),
#  Combined(employer='Romaguera, Welch and Haley', department='Engineering', employee_id='14-6523887', ssn='120-98-4054', first_name='Lorry', last_name='Hitter', gender='Male', language='Kazakh', last_updated=datetime.date(2017, 12, 1), created=datetime.date(2016, 7, 23), vehicle_make='Acura', vehicle_model='RL', model_year=2003),
#  Combined(employer='Paucek, Huels and Bauch', department='Accounting', employee_id='21-1452824', ssn='121-98-3948', first_name='Sal', last_name='Le Lievre', gender='Male', language='Croatian', last_updated=datetime.date(2017, 8, 23), created=datetime.date(2016, 6, 26), vehicle_make='Pontiac', vehicle_model='Montana', model_year=2002),
#  Combined(employer='Hayes-Trantow', department='Support', employee_id='07-2855255', ssn='123-05-3229', first_name='Spenser', last_name='Shucksmith', gender='Male', language='Bosnian', last_updated=datetime.date(2017, 8, 16), created=datetime.date(2016, 10, 23), vehicle_make='Jaguar', vehicle_model='X-Type', model_year=2003),
#  Combined(employer='Cruickshank, Legros and Keebler', department='Research and Development', employee_id='57-1590433', ssn='123-62-2832', first_name='Kare', last_name='Barhams', gender='Female', language='Tajik', last_updated=datetime.date(2017, 9, 11), created=datetime.date(2016, 10, 22), vehicle_make='Cadillac', vehicle_model='Catera', model_year=1999),
#  Combined(employer='Tromp-Leffler', department='Support', employee_id='02-6267170', ssn='127-49-2473', first_name='Quinta', last_name='Rippingall', gender='Female', language='Haitian Creole', last_updated=datetime.date(2017, 8, 31), created=datetime.date(2016, 8, 29), vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2004),
#  Combined(employer='Kulas-Corwin', department='Sales', employee_id='78-0632027', ssn='127-68-4232', first_name='Tresa', last_name='Verheyden', gender='Female', language='Icelandic', last_updated=datetime.date(2017, 3, 20), created=datetime.date(2016, 8, 19), vehicle_make='Scion', vehicle_model='xB', model_year=2004),
#  Combined(employer='MacGyver, Wiegand and Grant', department='Product Management', employee_id='77-4182531', ssn='127-93-3548', first_name='Mellicent', last_name='Ingham', gender='Female', language='Lao', last_updated=datetime.date(2017, 9, 10), created=datetime.date(2016, 7, 23), vehicle_make='Jeep', vehicle_model='Grand Cherokee', model_year=2007),
#  Combined(employer='Vandervort, Bernier and Morissette', department='Human Resources', employee_id='14-4998615', ssn='128-53-0369', first_name='Chucho', last_name='Rikel', gender='Male', language='Croatian', last_updated=datetime.date(2017, 8, 10), created=datetime.date(2016, 12, 19), vehicle_make='Audi', vehicle_model='A4', model_year=2010),
#  Combined(employer='King-Donnelly', department='Training', employee_id='82-0573004', ssn='128-53-7952', first_name='Tobie', last_name='Newhouse', gender='Male', language='Luxembourgish', last_updated=datetime.date(2017, 8, 31), created=datetime.date(2016, 7, 29), vehicle_make='Dodge', vehicle_model='Neon', model_year=1995),
#  Combined(employer='Harris Inc', department='Support', employee_id='53-7535536', ssn='128-56-6040', first_name='Jinny', last_name='Stebbings', gender='Female', language='Armenian', last_updated=datetime.date(2017, 8, 13), created=datetime.date(2016, 3, 21), vehicle_make='BMW', vehicle_model='M', model_year=2001),
#  Combined(employer='Gibson and Sons', department='Sales', employee_id='57-8173633', ssn='131-81-4310', first_name='Jemie', last_name='Manilo', gender='Female', language='Finnish', last_updated=datetime.date(2018, 3, 21), created=datetime.date(2016, 2, 3), vehicle_make='Land Rover', vehicle_model='Range Rover Sport', model_year=2012),
#  Combined(employer='Hyatt LLC', department='Training', employee_id='96-9647102', ssn='135-86-9625', first_name='Tilly', last_name='Meir', gender='Female', language='Gagauz', last_updated=datetime.date(2017, 12, 22), created=datetime.date(2016, 2, 28), vehicle_make='Toyota', vehicle_model='Tundra', model_year=2004),
#  Combined(employer='Schuster Group', department='Research and Development', employee_id='72-4728604', ssn='137-13-1889', first_name='Tedman', last_name="O'Donnelly", gender='Male', language='Bislama', last_updated=datetime.date(2017, 12, 24), created=datetime.date(2016, 3, 1), vehicle_make='Infiniti', vehicle_model='G', model_year=2005),
#  Combined(employer='Homenick-Beer', department='Product Management', employee_id='01-9334133', ssn='138-65-4579', first_name='Davidson', last_name='Gregoraci', gender='Male', language='Luxembourgish', last_updated=datetime.date(2017, 4, 17), created=datetime.date(2016, 12, 17), vehicle_make='Oldsmobile', vehicle_model='Achieva', model_year=1992),
#  Combined(employer='VonRueden-Torphy', department='Business Development', employee_id='10-6636122', ssn='138-67-1198', first_name='Pam', last_name='Tofful', gender='Female', language='Bislama', last_updated=datetime.date(2018, 3, 4), created=datetime.date(2016, 9, 24), vehicle_make='Lexus', vehicle_model='RX', model_year=2003),
#  Combined(employer='Gusikowski-Block', department='Legal', employee_id='41-1454732', ssn='139-94-5865', first_name='Donalt', last_name='Plewes', gender='Male', language='Haitian Creole', last_updated=datetime.date(2017, 8, 19), created=datetime.date(2016, 9, 10), vehicle_make='Volkswagen', vehicle_model='Cabriolet', model_year=1990),
#  Combined(employer='Pollich-Heathcote', department='Product Management', employee_id='12-2844710', ssn='139-99-6417', first_name='Susanetta', last_name='Nazaret', gender='Female', language='Punjabi', last_updated=datetime.date(2018, 1, 17), created=datetime.date(2016, 12, 21), vehicle_make='Volvo', vehicle_model='V70', model_year=2002),
#  Combined(employer='Bogisich Inc', department='Human Resources', employee_id='34-7172919', ssn='140-33-9727', first_name='Price', last_name='Butterwick', gender='Male', language='Belarusian', last_updated=datetime.date(2017, 9, 21), created=datetime.date(2016, 1, 27), vehicle_make='Mitsubishi', vehicle_model='Lancer', model_year=2003),
#  Combined(employer='Gutkowski Inc', department='Engineering', employee_id='83-4836768', ssn='140-58-8263', first_name='Tim', last_name='Bergin', gender='Female', language='Maori', last_updated=datetime.date(2017, 11, 12), created=datetime.date(2016, 12, 14), vehicle_make='Volvo', vehicle_model='XC90', model_year=2009),
#  Combined(employer='Greenholt LLC', department='Sales', employee_id='84-5391800', ssn='141-15-0543', first_name='Candy', last_name='Murtagh', gender='Female', language='Montenegrin', last_updated=datetime.date(2017, 9, 27), created=datetime.date(2016, 7, 17), vehicle_make='Toyota', vehicle_model='Corolla', model_year=2000),
#  Combined(employer='Hartmann Inc', department='Support', employee_id='26-7276512', ssn='141-88-9721', first_name='Cyrille', last_name='Capponer', gender='Male', language='Tswana', last_updated=datetime.date(2018, 1, 24), created=datetime.date(2016, 12, 20), vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2011),
#  Combined(employer='Zboncak-Gulgowski', department='Marketing', employee_id='05-0368584', ssn='142-77-4616', first_name='Barron', last_name='Victoria', gender='Male', language='Assamese', last_updated=datetime.date(2017, 7, 16), created=datetime.date(2016, 7, 30), vehicle_make='Chevrolet', vehicle_model='Prizm', model_year=1999),
#  Combined(employer='Altenwerth-Emard', department='Marketing', employee_id='30-5847411', ssn='142-87-3416', first_name='Margaux', last_name='Wintringham', gender='Female', language='Tajik', last_updated=datetime.date(2017, 5, 3), created=datetime.date(2016, 12, 26), vehicle_make='Ford', vehicle_model='Thunderbird', model_year=2005),
#  Combined(employer='Cronin Inc', department='Business Development', employee_id='08-3106397', ssn='143-17-4714', first_name='Hallie', last_name='Jeggo', gender='Female', language='Greek', last_updated=datetime.date(2017, 7, 21), created=datetime.date(2016, 2, 9), vehicle_make='Nissan', vehicle_model='Frontier', model_year=1999),
#  Combined(employer='Dibbert LLC', department='Support', employee_id='09-9620598', ssn='145-35-5124', first_name='Leon', last_name='Boyson', gender='Male', language='Dhivehi', last_updated=datetime.date(2018, 2, 20), created=datetime.date(2016, 10, 3), vehicle_make='GMC', vehicle_model='Savana 1500', model_year=1999),
#  Combined(employer='Tromp Inc', department='Research and Development', employee_id='06-3360383', ssn='145-78-3985', first_name='Baron', last_name='Cocci', gender='Male', language='Mongolian', last_updated=datetime.date(2017, 6, 10), created=datetime.date(2016, 9, 23), vehicle_make='Mercedes-Benz', vehicle_model='E-Class', model_year=1993),
#  Combined(employer='Greenholt-Gusikowski', department='Engineering', employee_id='16-6006875', ssn='147-33-1463', first_name='Bendicty', last_name='Gentry', gender='Male', language='Papiamento', last_updated=datetime.date(2018, 2, 9), created=datetime.date(2016, 5, 31), vehicle_make='GMC', vehicle_model='Vandura G1500', model_year=1995),
#  Combined(employer='Tremblay, Jacobs and Swift', department='Training', employee_id='46-1648855', ssn='147-47-8577', first_name='Janessa', last_name='Growy', gender='Female', language='Gujarati', last_updated=datetime.date(2017, 4, 2), created=datetime.date(2016, 12, 11), vehicle_make='Mitsubishi', vehicle_model='GTO', model_year=1996),
#  Combined(employer='Bashirian-Moen', department='Training', employee_id='51-9115041', ssn='147-63-3462', first_name='Aime', last_name='Di Antonio', gender='Female', language='Tok Pisin', last_updated=datetime.date(2018, 2, 2), created=datetime.date(2016, 7, 17), vehicle_make='Ford', vehicle_model='Explorer', model_year=2005),
#  Combined(employer='Balistreri Inc', department='Sales', employee_id='92-8183627', ssn='149-18-7272', first_name='Andrey', last_name='Bettley', gender='Male', language='Papiamento', last_updated=datetime.date(2017, 8, 31), created=datetime.date(2016, 10, 21), vehicle_make='Mercedes-Benz', vehicle_model='500SEL', model_year=1992),
#  Combined(employer='Eichmann, Quigley and Macejkovic', department='Business Development', employee_id='48-8059597', ssn='149-45-6482', first_name='Wheeler', last_name='Harbottle', gender='Male', language='Georgian', last_updated=datetime.date(2017, 9, 2), created=datetime.date(2016, 2, 23), vehicle_make='GMC', vehicle_model='3500 Club Coupe', model_year=1995),
#  Combined(employer='Bosco-Kunde', department='Services', employee_id='55-1726090', ssn='150-64-6357', first_name='Helenka', last_name='Summerell', gender='Female', language='Bosnian', last_updated=datetime.date(2018, 2, 14), created=datetime.date(2016, 1, 28), vehicle_make='Cadillac', vehicle_model='Escalade', model_year=2000),
#  Combined(employer='Ratke-Raynor', department='Legal', employee_id='60-6687797', ssn='150-89-3343', first_name='Bram', last_name='Beetlestone', gender='Male', language='Dzongkha', last_updated=datetime.date(2017, 6, 4), created=datetime.date(2016, 4, 23), vehicle_make='Plymouth', vehicle_model='Laser', model_year=1993),
#  Combined(employer='Bergstrom-Boyle', department='Marketing', employee_id='72-3121170', ssn='151-54-3946', first_name='Piggy', last_name='Fishly', gender='Male', language='Nepali', last_updated=datetime.date(2018, 2, 8), created=datetime.date(2016, 10, 19), vehicle_make='Ford', vehicle_model='Probe', model_year=1996),
#  Combined(employer='Schinner, Swaniawski and Carter', department='Human Resources', employee_id='93-3103060', ssn='151-78-1397', first_name='Portia', last_name='Belshaw', gender='Female', language='Sotho', last_updated=datetime.date(2017, 7, 8), created=datetime.date(2016, 6, 11), vehicle_make='BMW', vehicle_model='M5', model_year=2000),
#  Combined(employer='Little, Hagenes and McKenzie', department='Training', employee_id='75-9906937', ssn='152-71-3526', first_name='Mel', last_name='Atkirk', gender='Female', language='Swedish', last_updated=datetime.date(2018, 2, 25), created=datetime.date(2016, 10, 8), vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2001),
#  Combined(employer='Gerlach, Bahringer and Rutherford', department='Accounting', employee_id='95-5604381', ssn='153-67-1309', first_name='Annelise', last_name='Yushin', gender='Female', language='French', last_updated=datetime.date(2017, 8, 16), created=datetime.date(2016, 12, 22), vehicle_make='Ford', vehicle_model='Taurus', model_year=1998),
#  Combined(employer='Gorczany LLC', department='Training', employee_id='62-8983936', ssn='154-17-7912', first_name='Ainslee', last_name='Branche', gender='Female', language='Hindi', last_updated=datetime.date(2017, 4, 19), created=datetime.date(2016, 1, 29), vehicle_make='Nissan', vehicle_model='Armada', model_year=2005),
#  Combined(employer='Little, Powlowski and Witting', department='Business Development', employee_id='42-4459617', ssn='156-18-7547', first_name='Trey', last_name='Payne', gender='Male', language='West Frisian', last_updated=datetime.date(2017, 9, 10), created=datetime.date(2016, 10, 20), vehicle_make='Subaru', vehicle_model='Legacy', model_year=2011),
#  Combined(employer='King LLC', department='Research and Development', employee_id='39-4026042', ssn='156-91-6848', first_name='Carol', last_name='Cromar', gender='Female', language='Amharic', last_updated=datetime.date(2017, 8, 30), created=datetime.date(2016, 5, 7), vehicle_make='Acura', vehicle_model='TL', model_year=2005),
#  Combined(employer='Konopelski-Vandervort', department='Legal', employee_id='87-8332368', ssn='157-17-9982', first_name='Ardyce', last_name='Kuhnel', gender='Female', language='Danish', last_updated=datetime.date(2017, 4, 17), created=datetime.date(2016, 3, 17), vehicle_make='Audi', vehicle_model='Q7', model_year=2007),
#  Combined(employer='Reichel Group', department='Training', employee_id='10-5605387', ssn='157-38-7090', first_name='Johannes', last_name='Bugge', gender='Male', language='Afrikaans', last_updated=datetime.date(2017, 3, 24), created=datetime.date(2016, 9, 15), vehicle_make='Dodge', vehicle_model='Dakota Club', model_year=2005),
#  Combined(employer='Gerhold-Marquardt', department='Research and Development', employee_id='25-6013938', ssn='157-51-5269', first_name='Melisse', last_name='Petkov', gender='Female', language='Punjabi', last_updated=datetime.date(2017, 11, 4), created=datetime.date(2016, 6, 17), vehicle_make='BMW', vehicle_model='Z3', model_year=1996),
#  Combined(employer='Greenholt-Hermiston', department='Business Development', employee_id='66-9841280', ssn='161-36-9710', first_name='Melina', last_name='MacDavitt', gender='Female', language='Polish', last_updated=datetime.date(2017, 7, 3), created=datetime.date(2016, 6, 9), vehicle_make='Mercedes-Benz', vehicle_model='SLK-Class', model_year=1999),
#  Combined(employer='Oberbrunner, Donnelly and Gibson', department='Human Resources', employee_id='83-2548521', ssn='161-53-4778', first_name='Kiri', last_name='Ciccone', gender='Female', language='Kyrgyz', last_updated=datetime.date(2017, 12, 3), created=datetime.date(2016, 12, 9), vehicle_make='Ford', vehicle_model='Mustang', model_year=1995),
#  Combined(employer='Roberts Group', department='Product Management', employee_id='07-6620387', ssn='163-68-8070', first_name='Vassily', last_name='MacCarlich', gender='Male', language='Filipino', last_updated=datetime.date(2017, 9, 6), created=datetime.date(2016, 10, 23), vehicle_make='Lincoln', vehicle_model='Continental', model_year=1998),
#  Combined(employer='Olson-Lynch', department='Business Development', employee_id='50-7113609', ssn='163-98-1022', first_name='Babbette', last_name='Crystal', gender='Female', language='Lithuanian', last_updated=datetime.date(2017, 3, 26), created=datetime.date(2016, 3, 22), vehicle_make='Honda', vehicle_model='Civic', model_year=2012),
#  Combined(employer='Quitzon, Rempel and Hane', department='Business Development', employee_id='03-4767523', ssn='164-11-9849', first_name='Clemence', last_name='Aujean', gender='Female', language='Albanian', last_updated=datetime.date(2017, 6, 24), created=datetime.date(2016, 4, 20), vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=2001),
#  Combined(employer='Carroll, Konopelski and Wunsch', department='Research and Development', employee_id='43-4797129', ssn='166-10-4488', first_name='Lester', last_name='Keyson', gender='Male', language='Bislama', last_updated=datetime.date(2017, 8, 14), created=datetime.date(2016, 7, 2), vehicle_make='Cadillac', vehicle_model='DTS', model_year=2008),
#  Combined(employer='Howell LLC', department='Business Development', employee_id='70-2399476', ssn='167-39-2377', first_name='Reyna', last_name='Ullyatt', gender='Female', language='Portuguese', last_updated=datetime.date(2017, 10, 31), created=datetime.date(2016, 2, 3), vehicle_make='GMC', vehicle_model='3500', model_year=1998),
#  Combined(employer='Johnson Inc', department='Services', employee_id='34-7741883', ssn='168-02-5324', first_name='Dane', last_name='Cornick', gender='Male', language='Tajik', last_updated=datetime.date(2018, 1, 4), created=datetime.date(2016, 1, 29), vehicle_make='Volkswagen', vehicle_model='Fox', model_year=1989),
#  Combined(employer='Corwin and Sons', department='Legal', employee_id='15-8160997', ssn='168-19-8754', first_name='Teddie', last_name='Ingliss', gender='Male', language='Norwegian', last_updated=datetime.date(2017, 6, 10), created=datetime.date(2016, 9, 27), vehicle_make='Toyota', vehicle_model='MR2', model_year=1993),
#  Combined(employer='Toy-Jakubowski', department='Engineering', employee_id='17-8085199', ssn='168-89-6661', first_name='Vergil', last_name='Cecere', gender='Male', language='Tetum', last_updated=datetime.date(2017, 7, 17), created=datetime.date(2016, 4, 30), vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1964),
#  Combined(employer='Murphy, Windler and Bartoletti', department='Legal', employee_id='02-6976472', ssn='170-65-3388', first_name='Salvidor', last_name='Larcher', gender='Male', language='Burmese', last_updated=datetime.date(2017, 3, 5), created=datetime.date(2016, 6, 15), vehicle_make='Dodge', vehicle_model='Caravan', model_year=2010),
#  Combined(employer='Batz Inc', department='Support', employee_id='49-2738721', ssn='171-27-7781', first_name='Phillida', last_name='Cleeve', gender='Female', language='Lao', last_updated=datetime.date(2017, 3, 5), created=datetime.date(2016, 9, 23), vehicle_make='Ford', vehicle_model='Mustang', model_year=1985),
#  Combined(employer='Jast and Sons', department='Services', employee_id='38-6141294', ssn='172-23-7739', first_name='Everett', last_name='Turneaux', gender='Male', language='Kyrgyz', last_updated=datetime.date(2018, 3, 2), created=datetime.date(2016, 5, 12), vehicle_make='Mazda', vehicle_model='Mazdaspeed 3', model_year=2011),
#  Combined(employer='Roberts LLC', department='Research and Development', employee_id='91-2028080', ssn='172-77-4263', first_name='Alex', last_name='Udie', gender='Male', language='French', last_updated=datetime.date(2017, 10, 11), created=datetime.date(2016, 9, 10), vehicle_make='Volvo', vehicle_model='S60', model_year=2002),
#  Combined(employer='Zulauf, Hudson and Wisozk', department='Research and Development', employee_id='39-1896194', ssn='173-99-7372', first_name='Hedwiga', last_name='Gee', gender='Female', language='Danish', last_updated=datetime.date(2018, 3, 3), created=datetime.date(2016, 10, 26), vehicle_make='Kia', vehicle_model='Sephia', model_year=1997),
#  Combined(employer='Jast-Quitzon', department='Human Resources', employee_id='67-5707294', ssn='174-51-9992', first_name='Drucie', last_name='Travers', gender='Female', language='Swati', last_updated=datetime.date(2017, 3, 3), created=datetime.date(2016, 5, 17), vehicle_make='Chevrolet', vehicle_model='Beretta', model_year=1994),
#  Combined(employer='Green-Waelchi', department='Engineering', employee_id='29-7065788', ssn='174-87-2537', first_name='Benton', last_name='Nolte', gender='Male', language='Persian', last_updated=datetime.date(2017, 9, 30), created=datetime.date(2016, 8, 1), vehicle_make='Ford', vehicle_model='Taurus', model_year=1991),
#  Combined(employer='MacGyver-Hartmann', department='Accounting', employee_id='77-4207310', ssn='176-99-5851', first_name='Olivero', last_name='Janse', gender='Male', language='Moldovan', last_updated=datetime.date(2017, 4, 1), created=datetime.date(2016, 12, 3), vehicle_make='Jeep', vehicle_model='Commander', model_year=2007),
#  Combined(employer='McGlynn LLC', department='Support', employee_id='35-4393230', ssn='179-88-2790', first_name='Errick', last_name='Charsley', gender='Male', language='Japanese', last_updated=datetime.date(2017, 3, 23), created=datetime.date(2016, 3, 6), vehicle_make='Chevrolet', vehicle_model='Malibu', model_year=2013),
#  Combined(employer='Little, Herzog and Mertz', department='Legal', employee_id='45-9164509', ssn='181-07-4434', first_name='Ferdinande', last_name='Probet', gender='Female', language='Catalan', last_updated=datetime.date(2017, 10, 7), created=datetime.date(2016, 11, 11), vehicle_make='Chevrolet', vehicle_model='Impala SS', model_year=1995),
#  Combined(employer='Kertzmann-Reichel', department='Research and Development', employee_id='67-0581933', ssn='181-28-8337', first_name='Fan', last_name='Hillyatt', gender='Female', language='Moldovan', last_updated=datetime.date(2017, 11, 30), created=datetime.date(2016, 4, 27), vehicle_make='GMC', vehicle_model='Canyon', model_year=2004),
#  Combined(employer='Douglas, Funk and Schowalter', department='Services', employee_id='77-2512148', ssn='181-88-6077', first_name='Ebba', last_name='Wozencroft', gender='Female', language='German', last_updated=datetime.date(2017, 8, 16), created=datetime.date(2016, 9, 15), vehicle_make='Suzuki', vehicle_model='XL-7', model_year=2008),
#  Combined(employer='Bayer-Kunze', department='Support', employee_id='86-6996270', ssn='182-15-5082', first_name='Lavinie', last_name='Niess', gender='Female', language='Swahili', last_updated=datetime.date(2017, 10, 2), created=datetime.date(2016, 10, 16), vehicle_make='Mercedes-Benz', vehicle_model='S-Class', model_year=1988),
#  Combined(employer='Kiehn, Hansen and Will', department='Support', employee_id='94-8005696', ssn='182-81-4541', first_name='Sunny', last_name='Ferrarini', gender='Male', language='Swedish', last_updated=datetime.date(2017, 7, 5), created=datetime.date(2016, 7, 23), vehicle_make='Jeep', vehicle_model='Grand Cherokee', model_year=1997),
#  Combined(employer='Kling-Howe', department='Research and Development', employee_id='71-7470887', ssn='183-10-5024', first_name='Curran', last_name='Squires', gender='Male', language='Romanian', last_updated=datetime.date(2017, 11, 3), created=datetime.date(2016, 9, 8), vehicle_make='Maserati', vehicle_model='Spyder', model_year=1991),
#  Combined(employer='Quitzon-Morissette', department='Product Management', employee_id='81-5434446', ssn='184-60-6243', first_name='Fern', last_name='Demogeot', gender='Female', language='Tok Pisin', last_updated=datetime.date(2018, 2, 26), created=datetime.date(2016, 6, 16), vehicle_make='Ford', vehicle_model='Mustang', model_year=1998),
#  Combined(employer='Bergstrom-Daniel', department='Marketing', employee_id='31-7381298', ssn='184-84-1003', first_name='Bary', last_name='Buzin', gender='Male', language='Aymara', last_updated=datetime.date(2017, 10, 15), created=datetime.date(2016, 11, 17), vehicle_make='Mercury', vehicle_model='Mystique', model_year=1997),
#  Combined(employer='Lubowitz-Franecki', department='Product Management', employee_id='68-5287750', ssn='184-94-5241', first_name='Manfred', last_name='McCrillis', gender='Male', language='Swati', last_updated=datetime.date(2017, 3, 28), created=datetime.date(2016, 6, 3), vehicle_make='Audi', vehicle_model='90', model_year=1991),
#  Combined(employer='Quitzon, Stiedemann and Breitenberg', department='Services', employee_id='76-1399493', ssn='185-84-9868', first_name='Shandy', last_name='Ilyin', gender='Female', language='Northern Sotho', last_updated=datetime.date(2017, 7, 1), created=datetime.date(2016, 8, 8), vehicle_make='Mercury', vehicle_model='Sable', model_year=2001),
#  Combined(employer='Turner-Connelly', department='Research and Development', employee_id='92-1687621', ssn='186-65-7773', first_name='Hazlett', last_name='Arney', gender='Male', language='Marathi', last_updated=datetime.date(2017, 6, 9), created=datetime.date(2016, 9, 17), vehicle_make='Mitsubishi', vehicle_model='Precis', model_year=1990),
#  Combined(employer='Kling, Prosacco and Wisoky', department='Accounting', employee_id='77-0491080', ssn='188-20-9317', first_name='Clifford', last_name='Sedgemore', gender='Male', language='Thai', last_updated=datetime.date(2017, 12, 26), created=datetime.date(2016, 6, 5), vehicle_make='Chevrolet', vehicle_model='Avalanche 2500', model_year=2003),
#  Combined(employer="Von, O'Kon and Runolfsdottir", department='Research and Development', employee_id='34-6414700', ssn='188-40-4336', first_name='Belita', last_name='Camolli', gender='Female', language='Telugu', last_updated=datetime.date(2017, 12, 27), created=datetime.date(2016, 6, 30), vehicle_make='Mercedes-Benz', vehicle_model='E-Class', model_year=1985),
#  Combined(employer='McLaughlin-Botsford', department='Business Development', employee_id='60-2450272', ssn='189-26-5696', first_name='Arnold', last_name='Pepis', gender='Male', language='Tok Pisin', last_updated=datetime.date(2017, 8, 8), created=datetime.date(2016, 9, 9), vehicle_make='BMW', vehicle_model='8 Series', model_year=1995),
#  Combined(employer='Smitham-Blick', department='Engineering', employee_id='07-3918459', ssn='190-05-6987', first_name='Gorden', last_name='Clemonts', gender='Male', language='West Frisian', last_updated=datetime.date(2017, 6, 6), created=datetime.date(2016, 2, 17), vehicle_make='Subaru', vehicle_model='Legacy', model_year=1990),
#  Combined(employer='Reilly and Sons', department='Product Management', employee_id='00-2155545', ssn='190-53-4517', first_name='Hadlee', last_name='Rohan', gender='Male', language='Swahili', last_updated=datetime.date(2018, 2, 12), created=datetime.date(2016, 4, 15), vehicle_make='Hyundai', vehicle_model='Sonata', model_year=1993),
#  Combined(employer='Keeling, Hansen and Mertz', department='Training', employee_id='86-3420084', ssn='191-15-3194', first_name='Calhoun', last_name='Mugford', gender='Male', language='Thai', last_updated=datetime.date(2017, 7, 27), created=datetime.date(2016, 5, 23), vehicle_make='Mercury', vehicle_model='Grand Marquis', model_year=2009),
#  Combined(employer='Mante Inc', department='Business Development', employee_id='39-8018810', ssn='192-54-0695', first_name='Trev', last_name='Ruppeli', gender='Male', language='Maori', last_updated=datetime.date(2017, 3, 18), created=datetime.date(2016, 11, 16), vehicle_make='Volvo', vehicle_model='C70', model_year=1998),
#  Combined(employer='Hodkiewicz, Rau and Ryan', department='Marketing', employee_id='29-2776451', ssn='195-23-5731', first_name='Talyah', last_name='Canny', gender='Female', language='Portuguese', last_updated=datetime.date(2017, 5, 22), created=datetime.date(2016, 10, 23), vehicle_make='Saturn', vehicle_model='Outlook', model_year=2007),
#  Combined(employer='Farrell and Sons', department='Product Management', employee_id='85-3648779', ssn='199-45-0804', first_name='Consolata', last_name='Pigram', gender='Female', language='Guarana', last_updated=datetime.date(2017, 6, 23), created=datetime.date(2016, 11, 7), vehicle_make='Suzuki', vehicle_model='XL-7', model_year=2003),
#  Combined(employer='Heathcote-Torp', department='Product Management', employee_id='77-2681193', ssn='199-54-4639', first_name='Ellene', last_name='Dowrey', gender='Female', language='Nepali', last_updated=datetime.date(2018, 2, 23), created=datetime.date(2016, 4, 5), vehicle_make='Mercury', vehicle_model='Mountaineer', model_year=2006),
#  Combined(employer='Hilpert, Kassulke and Gutkowski', department='Research and Development', employee_id='02-6484055', ssn='200-81-7151', first_name='Merilyn', last_name='Tink', gender='Female', language='Bengali', last_updated=datetime.date(2017, 11, 19), created=datetime.date(2016, 7, 31), vehicle_make='Mitsubishi', vehicle_model='Tredia', model_year=1985),
#  Combined(employer="Will, Lemke and O'Hara", department='Marketing', employee_id='68-7719884', ssn='201-53-1249', first_name='Jammal', last_name='Dohmer', gender='Male', language='Danish', last_updated=datetime.date(2017, 11, 25), created=datetime.date(2016, 10, 7), vehicle_make='Acura', vehicle_model='NSX', model_year=1996),
#  Combined(employer='Schuppe-Dickinson', department='Services', employee_id='47-8932065', ssn='202-84-1146', first_name='Dore', last_name='Woodrup', gender='Male', language='Afrikaans', last_updated=datetime.date(2017, 4, 1), created=datetime.date(2016, 7, 21), vehicle_make='Chrysler', vehicle_model='LHS', model_year=2000),
#  Combined(employer='Kling-Graham', department='Marketing', employee_id='08-4055205', ssn='203-35-7648', first_name='Budd', last_name='Artiss', gender='Male', language='Norwegian', last_updated=datetime.date(2017, 12, 1), created=datetime.date(2016, 8, 2), vehicle_make='Volvo', vehicle_model='960', model_year=1992),
#  Combined(employer='MacGyver, Armstrong and Murray', department='Research and Development', employee_id='68-8311842', ssn='205-69-7375', first_name='Cacilia', last_name='Kneesha', gender='Female', language='Indonesian', last_updated=datetime.date(2018, 2, 27), created=datetime.date(2016, 5, 19), vehicle_make='Subaru', vehicle_model='Outback', model_year=2011),
#  Combined(employer='Goodwin-Oberbrunner', department='Accounting', employee_id='07-0291024', ssn='205-87-2423', first_name='Oralla', last_name='Kearle', gender='Female', language='Zulu', last_updated=datetime.date(2018, 1, 1), created=datetime.date(2016, 2, 16), vehicle_make='Chevrolet', vehicle_model='Express 2500', model_year=1999),
#  Combined(employer='Russel-Terry', department='Engineering', employee_id='70-0439540', ssn='206-28-6674', first_name='Con', last_name='Mansbridge', gender='Male', language='Haitian Creole', last_updated=datetime.date(2017, 10, 14), created=datetime.date(2016, 8, 1), vehicle_make='Mitsubishi', vehicle_model='Chariot', model_year=1994),
#  Combined(employer='Hickle, Beatty and McCullough', department='Business Development', employee_id='95-7755368', ssn='206-83-8848', first_name='Ardyth', last_name='Arger', gender='Female', language='Gagauz', last_updated=datetime.date(2017, 11, 8), created=datetime.date(2016, 4, 11), vehicle_make='Volvo', vehicle_model='S60', model_year=2011),
#  Combined(employer='Volkman-King', department='Training', employee_id='29-5040096', ssn='208-80-5879', first_name='Rockie', last_name='Fryd', gender='Male', language='Korean', last_updated=datetime.date(2017, 10, 16), created=datetime.date(2016, 3, 31), vehicle_make='Mercury', vehicle_model='Mountaineer', model_year=2009),
#  Combined(employer='Senger, Fay and Schuppe', department='Marketing', employee_id='05-9734435', ssn='209-50-8146', first_name='Kenna', last_name='Meryett', gender='Female', language='Czech', last_updated=datetime.date(2018, 3, 13), created=datetime.date(2016, 4, 10), vehicle_make='Chevrolet', vehicle_model='Sportvan G20', model_year=1992),
#  Combined(employer='Lesch, Hartmann and Leffler', department='Engineering', employee_id='32-6936796', ssn='209-58-4708', first_name='Stephanus', last_name='Creboe', gender='Male', language='Latvian', last_updated=datetime.date(2018, 2, 8), created=datetime.date(2016, 6, 17), vehicle_make='Buick', vehicle_model='LaCrosse', model_year=2009),
#  Combined(employer='Weber, Reynolds and Brakus', department='Training', employee_id='26-0100410', ssn='210-91-4729', first_name='Tamarra', last_name='Minchella', gender='Female', language='Greek', last_updated=datetime.date(2017, 7, 11), created=datetime.date(2016, 12, 4), vehicle_make='Acura', vehicle_model='Integra', model_year=1997),
#  Combined(employer='Renner LLC', department='Services', employee_id='29-6760360', ssn='211-04-1734', first_name='Jeana', last_name='Girardeau', gender='Female', language='Dzongkha', last_updated=datetime.date(2018, 3, 11), created=datetime.date(2016, 8, 30), vehicle_make='Ford', vehicle_model='E-Series', model_year=2011),
#  Combined(employer='Lind and Sons', department='Services', employee_id='93-4909831', ssn='211-13-5247', first_name='Wes', last_name='Weinberg', gender='Male', language='French', last_updated=datetime.date(2018, 2, 22), created=datetime.date(2016, 12, 20), vehicle_make='Mercedes-Benz', vehicle_model='SLR McLaren', model_year=2005),
#  Combined(employer='Sawayn, Marvin and Rempel', department='Research and Development', employee_id='74-6068283', ssn='211-15-5182', first_name='Gene', last_name='Bassilashvili', gender='Female', language='Swedish', last_updated=datetime.date(2017, 4, 15), created=datetime.date(2016, 3, 17), vehicle_make='Chrysler', vehicle_model='Town & Country', model_year=2010),
#  Combined(employer='Feil, Wunsch and Cassin', department='Human Resources', employee_id='45-3457627', ssn='211-19-6826', first_name='Noni', last_name='Meynell', gender='Female', language='Portuguese', last_updated=datetime.date(2018, 2, 12), created=datetime.date(2016, 8, 25), vehicle_make='Ford', vehicle_model='Econoline E150', model_year=1996),
#  Combined(employer='Hills-Luettgen', department='Engineering', employee_id='49-6662355', ssn='212-41-1496', first_name='Agnese', last_name='Lawes', gender='Female', language='Tamil', last_updated=datetime.date(2017, 7, 7), created=datetime.date(2016, 10, 27), vehicle_make='Volkswagen', vehicle_model='Eurovan', model_year=1995),
#  Combined(employer='Larson and Sons', department='Sales', employee_id='18-3961077', ssn='213-28-1395', first_name='Catlaina', last_name='Patullo', gender='Female', language='Bengali', last_updated=datetime.date(2017, 6, 4), created=datetime.date(2016, 6, 11), vehicle_make='Ford', vehicle_model='Mustang', model_year=2002),
#  Combined(employer='Sipes LLC', department='Business Development', employee_id='13-5040342', ssn='214-29-1189', first_name='Chandler', last_name='Gonsalvo', gender='Male', language='Haitian Creole', last_updated=datetime.date(2018, 2, 16), created=datetime.date(2016, 6, 2), vehicle_make='Kia', vehicle_model='Sedona', model_year=2011),
#  Combined(employer='Aufderhar, Trantow and Goodwin', department='Marketing', employee_id='70-8647485', ssn='214-96-8581', first_name='Earlie', last_name='de Nore', gender='Male', language='Georgian', last_updated=datetime.date(2017, 4, 30), created=datetime.date(2016, 8, 18), vehicle_make='Kia', vehicle_model='Borrego', model_year=2009),
#  Combined(employer='Emmerich, Emmerich and Mertz', department='Business Development', employee_id='13-9720741', ssn='214-99-7584', first_name='Barny', last_name='Witherden', gender='Male', language='Czech', last_updated=datetime.date(2018, 2, 22), created=datetime.date(2016, 7, 14), vehicle_make='Saturn', vehicle_model='Outlook', model_year=2010),
#  Combined(employer='Quitzon Inc', department='Human Resources', employee_id='97-0142691', ssn='216-89-3812', first_name='Florian', last_name='Jaze', gender='Male', language='Croatian', last_updated=datetime.date(2018, 3, 11), created=datetime.date(2016, 7, 28), vehicle_make='Maybach', vehicle_model='Landaulet', model_year=2012),
#  Combined(employer='Nienow-Hegmann', department='Training', employee_id='81-6888800', ssn='217-71-3922', first_name='Hayes', last_name='Vallentin', gender='Male', language='Bengali', last_updated=datetime.date(2017, 11, 11), created=datetime.date(2016, 3, 4), vehicle_make='Volkswagen', vehicle_model='Corrado', model_year=1990),
#  Combined(employer='Gislason-Padberg', department='Sales', employee_id='20-8472919', ssn='217-81-5416', first_name='Gusta', last_name='Cruise', gender='Female', language='Tsonga', last_updated=datetime.date(2017, 12, 27), created=datetime.date(2016, 11, 20), vehicle_make='Ford', vehicle_model='Mustang', model_year=2005),
#  Combined(employer='Cormier, Weimann and Erdman', department='Accounting', employee_id='72-8208288', ssn='218-14-4448', first_name='Keary', last_name='Druhan', gender='Male', language='Dutch', last_updated=datetime.date(2017, 7, 22), created=datetime.date(2016, 6, 29), vehicle_make='Mitsubishi', vehicle_model='GTO', model_year=1999),
#  Combined(employer='Mraz, Stokes and MacGyver', department='Legal', employee_id='40-6893978', ssn='218-25-9873', first_name='Westbrooke', last_name='Succamore', gender='Male', language='Fijian', last_updated=datetime.date(2017, 5, 11), created=datetime.date(2016, 3, 11), vehicle_make='Honda', vehicle_model='Prelude', model_year=1997),
#  Combined(employer='Stokes-Hayes', department='Marketing', employee_id='50-1906989', ssn='218-31-1615', first_name='Trenton', last_name='Eggerton', gender='Male', language='Dari', last_updated=datetime.date(2017, 8, 3), created=datetime.date(2016, 5, 14), vehicle_make='Mitsubishi', vehicle_model='3000GT', model_year=1996),
#  Combined(employer='Johns, Corkery and Feeney', department='Services', employee_id='22-7439070', ssn='218-49-7300', first_name='Justinn', last_name='Sherebrooke', gender='Female', language='English', last_updated=datetime.date(2017, 12, 22), created=datetime.date(2016, 9, 17), vehicle_make='Plymouth', vehicle_model='Neon', model_year=1995),
#  Combined(employer='Hirthe, Doyle and Harvey', department='Training', employee_id='13-1135326', ssn='220-16-0476', first_name='Baxy', last_name='Brothwood', gender='Male', language='Kyrgyz', last_updated=datetime.date(2017, 3, 9), created=datetime.date(2016, 7, 4), vehicle_make='Lexus', vehicle_model='LX', model_year=2011),
#  Combined(employer='Brekke, Grady and Ruecker', department='Human Resources', employee_id='66-2984352', ssn='220-38-0208', first_name='Jess', last_name='Fulun', gender='Female', language='Gagauz', last_updated=datetime.date(2017, 11, 10), created=datetime.date(2016, 10, 28), vehicle_make='Ford', vehicle_model='Lightning', model_year=1994),
#  Combined(employer='Langosh, Blick and Bechtelar', department='Product Management', employee_id='55-6679606', ssn='223-67-9203', first_name='Markus', last_name='Radband', gender='Male', language='Bosnian', last_updated=datetime.date(2017, 8, 4), created=datetime.date(2016, 12, 2), vehicle_make='Chevrolet', vehicle_model='Impala', model_year=2002),
#  Combined(employer='Luettgen, Marks and Rosenbaum', department='Human Resources', employee_id='46-3461516', ssn='223-98-0846', first_name='Josy', last_name='Hadwick', gender='Female', language='Papiamento', last_updated=datetime.date(2017, 3, 29), created=datetime.date(2016, 6, 29), vehicle_make='Nissan', vehicle_model='GT-R', model_year=2012),
#  Combined(employer='Smith-Bergstrom', department='Sales', employee_id='11-8895205', ssn='224-12-3436', first_name='Alister', last_name='Eakle', gender='Male', language='Estonian', last_updated=datetime.date(2018, 1, 9), created=datetime.date(2016, 10, 6), vehicle_make='Kia', vehicle_model='Sportage', model_year=1998),
#  Combined(employer='Jacobson-Kuhn', department='Human Resources', employee_id='33-5097675', ssn='224-30-9267', first_name='Flori', last_name='Bagnal', gender='Female', language='Swedish', last_updated=datetime.date(2017, 12, 17), created=datetime.date(2016, 11, 13), vehicle_make='Chevrolet', vehicle_model='Avalanche', model_year=2009),
#  Combined(employer='Pollich, Hodkiewicz and Kris', department='Research and Development', employee_id='34-4050792', ssn='224-84-2271', first_name='Weider', last_name='Carlisle', gender='Male', language='Swedish', last_updated=datetime.date(2018, 1, 23), created=datetime.date(2016, 6, 14), vehicle_make='Jeep', vehicle_model='Liberty', model_year=2005),
#  Combined(employer='Deckow Group', department='Engineering', employee_id='49-2911011', ssn='224-99-0668', first_name='Brandy', last_name='Steed', gender='Male', language='Croatian', last_updated=datetime.date(2017, 4, 1), created=datetime.date(2016, 1, 3), vehicle_make='Acura', vehicle_model='TL', model_year=2008),
# ...
#  Combined(employer='Collier, Botsford and Ruecker', department='Engineering', employee_id='18-5849664', ssn='851-94-2162', first_name='Rodi', last_name='Mulrenan', gender='Female', language='Catalan', last_updated=datetime.date(2017, 10, 15), created=datetime.date(2016, 11, 28), vehicle_make='Chevrolet', vehicle_model='Cobalt', model_year=2010),
#  Combined(employer='Conn Group', department='Training', employee_id='09-7105416', ssn='852-15-7707', first_name='Mario', last_name='Lelande', gender='Male', language='Nepali', last_updated=datetime.date(2017, 12, 7), created=datetime.date(2016, 3, 17), vehicle_make='Mazda', vehicle_model='MX-5', model_year=2010),
#  Combined(employer='Moen Inc', department='Sales', employee_id='98-1092646', ssn='853-11-8953', first_name='Brice', last_name='Kyd', gender='Male', language='Dari', last_updated=datetime.date(2017, 12, 30), created=datetime.date(2016, 12, 24), vehicle_make='Pontiac', vehicle_model='Fiero', model_year=1987),
#  Combined(employer='Barrows Inc', department='Product Management', employee_id='06-3741043', ssn='853-47-3648', first_name='Olag', last_name='Belhome', gender='Male', language='Maltese', last_updated=datetime.date(2017, 11, 24), created=datetime.date(2016, 4, 22), vehicle_make='Infiniti', vehicle_model='I', model_year=2003),
#  Combined(employer='Thiel-Murray', department='Support', employee_id='96-2035605', ssn='854-68-7635', first_name='Eyde', last_name='McCunn', gender='Female', language='Moldovan', last_updated=datetime.date(2017, 5, 16), created=datetime.date(2016, 4, 29), vehicle_make='Pontiac', vehicle_model='Grand Prix', model_year=1991),
#  Combined(employer='Blanda-Ferry', department='Product Management', employee_id='74-9087432', ssn='854-71-2983', first_name='Rikki', last_name='Loveland', gender='Male', language='Dutch', last_updated=datetime.date(2017, 9, 6), created=datetime.date(2016, 11, 7), vehicle_make='Subaru', vehicle_model='SVX', model_year=1993),
#  Combined(employer='Dietrich Inc', department='Business Development', employee_id='79-1998214', ssn='854-79-5334', first_name='Bevan', last_name='Kolczynski', gender='Male', language='Swahili', last_updated=datetime.date(2017, 8, 29), created=datetime.date(2016, 3, 27), vehicle_make='Jeep', vehicle_model='Cherokee', model_year=1996),
#  Combined(employer='Lakin and Sons', department='Accounting', employee_id='41-4723930', ssn='856-27-9112', first_name='Virgilio', last_name='Kirrage', gender='Male', language='Pashto', last_updated=datetime.date(2017, 12, 25), created=datetime.date(2016, 3, 24), vehicle_make='BMW', vehicle_model='3 Series', model_year=2011),
#  Combined(employer='Kassulke, Ritchie and Braun', department='Accounting', employee_id='06-1382466', ssn='856-67-4080', first_name='Aggy', last_name='Cobley', gender='Female', language='Dhivehi', last_updated=datetime.date(2018, 3, 13), created=datetime.date(2016, 6, 22), vehicle_make='Dodge', vehicle_model='Grand Caravan', model_year=2007),
#  Combined(employer='Swaniawski Group', department='Services', employee_id='44-2276418', ssn='857-37-5902', first_name='Jenni', last_name='Swinyard', gender='Female', language='Hindi', last_updated=datetime.date(2018, 1, 20), created=datetime.date(2016, 10, 23), vehicle_make='Lotus', vehicle_model='Esprit', model_year=1996),
#  Combined(employer='Stark-Pouros', department='Training', employee_id='53-7456817', ssn='858-03-7735', first_name='Allayne', last_name='Wardingley', gender='Male', language='Kazakh', last_updated=datetime.date(2017, 4, 30), created=datetime.date(2016, 9, 4), vehicle_make='Porsche', vehicle_model='944', model_year=1984),
#  Combined(employer='Reinger Inc', department='Engineering', employee_id='80-2005731', ssn='860-89-2570', first_name='Otto', last_name='Burgwin', gender='Male', language='Finnish', last_updated=datetime.date(2017, 4, 15), created=datetime.date(2016, 6, 22), vehicle_make='Dodge', vehicle_model='Dakota', model_year=2007),
#  Combined(employer='Stokes Inc', department='Training', employee_id='12-6635955', ssn='861-50-6716', first_name='Norina', last_name='Yerbury', gender='Female', language='Indonesian', last_updated=datetime.date(2018, 3, 30), created=datetime.date(2016, 9, 16), vehicle_make='BMW', vehicle_model='M5', model_year=2007),
#  Combined(employer='Dicki, Green and White', department='Services', employee_id='87-1017676', ssn='862-20-0653', first_name='Wilfrid', last_name='Kid', gender='Male', language='Swedish', last_updated=datetime.date(2017, 5, 3), created=datetime.date(2016, 2, 4), vehicle_make='Mazda', vehicle_model='B-Series', model_year=2002),
#  Combined(employer='Bartoletti Inc', department='Support', employee_id='77-7239839', ssn='866-18-1440', first_name='Zachary', last_name='Branchflower', gender='Male', language='Papiamento', last_updated=datetime.date(2017, 5, 31), created=datetime.date(2016, 2, 2), vehicle_make='Volvo', vehicle_model='S60', model_year=2002),
#  Combined(employer='Douglas-Breitenberg', department='Business Development', employee_id='63-6285198', ssn='866-53-0625', first_name='Francene', last_name='Ehlerding', gender='Female', language='Latvian', last_updated=datetime.date(2018, 2, 24), created=datetime.date(2016, 12, 15), vehicle_make='Chevrolet', vehicle_model='Blazer', model_year=1997),
#  Combined(employer='Nitzsche-Walker', department='Engineering', employee_id='50-5681388', ssn='867-11-6007', first_name='Kennett', last_name='Barhims', gender='Male', language='Malayalam', last_updated=datetime.date(2018, 1, 25), created=datetime.date(2016, 10, 31), vehicle_make='Volvo', vehicle_model='S80', model_year=2001),
#  Combined(employer='Crist, Leuschke and Grimes', department='Legal', employee_id='09-8398802', ssn='867-13-6844', first_name='Clo', last_name='Skacel', gender='Female', language='Armenian', last_updated=datetime.date(2017, 10, 31), created=datetime.date(2016, 7, 17), vehicle_make='Land Rover', vehicle_model='Range Rover', model_year=1986),
#  Combined(employer='Emard Inc', department='Business Development', employee_id='49-2589434', ssn='867-88-2360', first_name='Gasper', last_name='Dohrmann', gender='Male', language='Dzongkha', last_updated=datetime.date(2018, 3, 11), created=datetime.date(2016, 11, 4), vehicle_make='Ford', vehicle_model='F-Series', model_year=1987),
#  Combined(employer='Abshire Inc', department='Research and Development', employee_id='55-8987515', ssn='868-32-1805', first_name='Joanna', last_name='Raycroft', gender='Female', language='Bosnian', last_updated=datetime.date(2017, 9, 29), created=datetime.date(2016, 11, 14), vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2007),
#  Combined(employer='Morissette, Rowe and Muller', department='Engineering', employee_id='73-9912953', ssn='870-93-1121', first_name='Elisha', last_name='Wonham', gender='Male', language='Hebrew', last_updated=datetime.date(2017, 3, 3), created=datetime.date(2016, 6, 21), vehicle_make='Mitsubishi', vehicle_model='Pajero', model_year=1998),
#  Combined(employer='Lueilwitz, Stokes and Kassulke', department='Marketing', employee_id='16-1937114', ssn='871-99-3191', first_name='Susann', last_name='Walrond', gender='Female', language='Amharic', last_updated=datetime.date(2017, 5, 8), created=datetime.date(2016, 2, 27), vehicle_make='Toyota', vehicle_model='Sienna', model_year=2000),
#  Combined(employer='Glover, Jacobs and Heidenreich', department='Sales', employee_id='72-1577952', ssn='872-18-9267', first_name='Roddy', last_name='Honeywood', gender='Male', language='Maltese', last_updated=datetime.date(2018, 3, 22), created=datetime.date(2016, 4, 27), vehicle_make='Audi', vehicle_model='A4', model_year=2010),
#  Combined(employer='Cummings-Mertz', department='Sales', employee_id='78-2291834', ssn='872-49-1288', first_name='Salaidh', last_name='Barthod', gender='Female', language='Finnish', last_updated=datetime.date(2017, 12, 6), created=datetime.date(2016, 6, 10), vehicle_make='Acura', vehicle_model='Integra', model_year=1997),
#  Combined(employer='Wilderman-Grimes', department='Engineering', employee_id='39-6055619', ssn='873-36-4733', first_name='Locke', last_name='Staries', gender='Male', language='Moldovan', last_updated=datetime.date(2017, 7, 23), created=datetime.date(2016, 7, 8), vehicle_make='Austin', vehicle_model='Mini Cooper', model_year=1964),
#  Combined(employer='Schultz-Medhurst', department='Support', employee_id='56-6050344', ssn='875-18-9454', first_name='Eustace', last_name='Kinnear', gender='Male', language='Hiri Motu', last_updated=datetime.date(2017, 3, 14), created=datetime.date(2016, 8, 19), vehicle_make='Mitsubishi', vehicle_model='Diamante', model_year=1993),
#  Combined(employer='Wunsch-Gleason', department='Services', employee_id='28-3015726', ssn='875-75-0495', first_name='Frasquito', last_name='Lammas', gender='Male', language='Polish', last_updated=datetime.date(2017, 12, 3), created=datetime.date(2016, 6, 12), vehicle_make='Hyundai', vehicle_model='Tiburon', model_year=2000),
#  Combined(employer='Daugherty, Gislason and Kreiger', department='Training', employee_id='25-5973403', ssn='881-19-5974', first_name='Lodovico', last_name='Gabby', gender='Male', language='Northern Sotho', last_updated=datetime.date(2018, 2, 4), created=datetime.date(2016, 10, 5), vehicle_make='Infiniti', vehicle_model='G', model_year=2004),
#  Combined(employer="O'Connell, Raynor and Veum", department='Sales', employee_id='16-0843654', ssn='881-88-7308', first_name='Maitilde', last_name='Davis', gender='Female', language='Tsonga', last_updated=datetime.date(2017, 8, 11), created=datetime.date(2016, 1, 18), vehicle_make='Subaru', vehicle_model='SVX', model_year=1994),
#  Combined(employer='Schumm Inc', department='Services', employee_id='18-8360445', ssn='881-95-7180', first_name='Homerus', last_name='Lamar', gender='Male', language='Macedonian', last_updated=datetime.date(2018, 1, 29), created=datetime.date(2016, 11, 24), vehicle_make='BMW', vehicle_model='M6', model_year=2009),
#  Combined(employer='Ziemann, Denesik and Casper', department='Research and Development', employee_id='71-6097002', ssn='887-41-7878', first_name='Bruce', last_name='Danieli', gender='Male', language='Tamil', last_updated=datetime.date(2017, 3, 27), created=datetime.date(2016, 9, 14), vehicle_make='Lexus', vehicle_model='GS', model_year=2013),
#  Combined(employer='Terry and Sons', department='Research and Development', employee_id='06-9390159', ssn='887-83-9002', first_name='Mab', last_name='Bozworth', gender='Female', language='Tok Pisin', last_updated=datetime.date(2017, 12, 19), created=datetime.date(2016, 5, 30), vehicle_make='Audi', vehicle_model='S6', model_year=2011),
#  Combined(employer='Herzog, Stehr and Quitzon', department='Engineering', employee_id='38-5385705', ssn='888-50-7008', first_name='Mayor', last_name='Gouley', gender='Male', language='Dzongkha', last_updated=datetime.date(2018, 3, 6), created=datetime.date(2016, 6, 9), vehicle_make='Nissan', vehicle_model='Armada', model_year=2008),
#  Combined(employer='Collier, Hilll and Hagenes', department='Training', employee_id='15-6651242', ssn='888-53-7684', first_name='Lanny', last_name='Perfect', gender='Male', language='Estonian', last_updated=datetime.date(2017, 9, 5), created=datetime.date(2016, 2, 12), vehicle_make='Volkswagen', vehicle_model='Jetta', model_year=1991),
#  Combined(employer='Reynolds, Nicolas and Morar', department='Engineering', employee_id='48-3998718', ssn='888-82-4928', first_name='Billye', last_name='Legat', gender='Female', language='Icelandic', last_updated=datetime.date(2017, 12, 8), created=datetime.date(2016, 11, 9), vehicle_make='Volvo', vehicle_model='S60', model_year=2005),
#  Combined(employer='Heller, Kihn and Bartoletti', department='Research and Development', employee_id='56-9393666', ssn='890-28-9962', first_name='Kingston', last_name='Spitell', gender='Male', language='Quechua', last_updated=datetime.date(2018, 1, 6), created=datetime.date(2016, 2, 22), vehicle_make='GMC', vehicle_model='Savana 1500', model_year=2000),
#  Combined(employer='Christiansen LLC', department='Sales', employee_id='66-1175841', ssn='893-12-0901', first_name='Dicky', last_name='Rohlfing', gender='Male', language='Oriya', last_updated=datetime.date(2018, 3, 27), created=datetime.date(2016, 6, 14), vehicle_make='Lotus', vehicle_model='Esprit', model_year=1991),
#  Combined(employer='Orn Inc', department='Human Resources', employee_id='38-4356300', ssn='893-17-7318', first_name='Nani', last_name='Bonelle', gender='Female', language='Kyrgyz', last_updated=datetime.date(2017, 7, 23), created=datetime.date(2016, 2, 28), vehicle_make='Chevrolet', vehicle_model='Lumina', model_year=1995),
#  Combined(employer='Flatley, Senger and Bernier', department='Services', employee_id='72-2633200', ssn='894-81-0628', first_name='Ree', last_name='Mordue', gender='Female', language='Tswana', last_updated=datetime.date(2017, 3, 7), created=datetime.date(2016, 7, 9), vehicle_make='Kia', vehicle_model='Sedona', model_year=2012),
#  Combined(employer='Hilll, Kunze and Beer', department='Human Resources', employee_id='90-4168298', ssn='895-26-1658', first_name='Nance', last_name='Danzelman', gender='Female', language='Icelandic', last_updated=datetime.date(2017, 4, 1), created=datetime.date(2016, 11, 22), vehicle_make='Toyota', vehicle_model='Land Cruiser', model_year=2003),
#  Combined(employer='Franecki LLC', department='Services', employee_id='63-7802530', ssn='895-26-5515', first_name='Frank', last_name='Mason', gender='Male', language='Northern Sotho', last_updated=datetime.date(2017, 5, 13), created=datetime.date(2016, 3, 24), vehicle_make='Acura', vehicle_model='TL', model_year=1999),
#  Combined(employer='Reilly-Jakubowski', department='Marketing', employee_id='77-6363112', ssn='897-76-7070', first_name='Glynnis', last_name='Tillerton', gender='Female', language='Nepali', last_updated=datetime.date(2017, 11, 27), created=datetime.date(2016, 12, 12), vehicle_make='BMW', vehicle_model='X3', model_year=2011),
#  Combined(employer='Bins-Gerhold', department='Sales', employee_id='89-9965641', ssn='898-03-3165', first_name='Sela', last_name='Vaillant', gender='Female', language='Arabic', last_updated=datetime.date(2017, 6, 1), created=datetime.date(2016, 7, 20), vehicle_make='Toyota', vehicle_model='Xtra', model_year=1994),
#  Combined(employer='Olson-Johnson', department='Support', employee_id='36-7761827', ssn='898-86-8860', first_name='Hershel', last_name='Few', gender='Male', language='Gagauz', last_updated=datetime.date(2017, 7, 3), created=datetime.date(2016, 11, 23), vehicle_make='Lotus', vehicle_model='Esprit', model_year=2003),
#  Combined(employer='Cronin LLC', department='Services', employee_id='83-8730953', ssn='899-09-1766', first_name='Joe', last_name='Myderscough', gender='Male', language='Filipino', last_updated=datetime.date(2017, 7, 31), created=datetime.date(2016, 10, 27), vehicle_make='Toyota', vehicle_model='Camry', model_year=2012),
#  Combined(employer='Little-Hansen', department='Business Development', employee_id='45-8154226', ssn='899-39-7179', first_name='Rani', last_name='Naisbitt', gender='Female', language='Greek', last_updated=datetime.date(2017, 8, 2), created=datetime.date(2016, 7, 27), vehicle_make='Infiniti', vehicle_model='FX', model_year=2006),
#  Combined(employer="Christiansen, Ondricka and O'Connell", department='Marketing', employee_id='32-7034344', ssn='899-39-7378', first_name='Lindsay', last_name='Colledge', gender='Female', language='Croatian', last_updated=datetime.date(2017, 3, 27), created=datetime.date(2016, 9, 4), vehicle_make='Toyota', vehicle_model='Land Cruiser', model_year=1999),
#  Combined(employer='Bednar LLC', department='Support', employee_id='16-6342889', ssn='899-47-6116', first_name='Tiphanie', last_name='Kevlin', gender='Female', language='Tetum', last_updated=datetime.date(2017, 6, 10), created=datetime.date(2016, 4, 29), vehicle_make='Volkswagen', vehicle_model='Phaeton', model_year=2005)]

# %%
from itertools import groupby

results.sort(key = lambda x: (x.gender, x.vehicle_make))
make_groups = groupby(results, key = lambda x: x.gender + ' ' + x.vehicle_make)
make_counts = ((key, sum(1 for model in models)) for key, models in make_groups)

counts_list = list(make_counts)
counts_list.sort(key = lambda x: (x[0].split(' ')[0], x[1]), reverse=True)
counts_list
# Out:
# [('Male Ford', 40),
#  ('Male Chevrolet', 30),
#  ('Male GMC', 28),
#  ('Male Mitsubishi', 28),
#  ('Male Dodge', 22),
#  ('Male Toyota', 21),
#  ('Male Mercedes-Benz', 19),
#  ('Male Volkswagen', 16),
#  ('Male Audi', 14),
#  ('Male Buick', 13),
#  ('Male Mazda', 13),
#  ('Male BMW', 12),
#  ('Male Mercury', 11),
#  ('Male Pontiac', 11),
#  ('Male Volvo', 10),
#  ('Male Cadillac', 9),
#  ('Male Honda', 9),
#  ('Male Hyundai', 8),
#  ('Male Saab', 8),
#  ('Male Subaru', 8),
#  ('Male Acura', 7),
#  ('Male Infiniti', 7),
#  ('Male Jeep', 7),
#  ('Male Lexus', 6),
#  ('Male Nissan', 6),
#  ('Male Kia', 5),
#  ('Male Lincoln', 5),
#  ('Male Lotus', 5),
#  ('Male Oldsmobile', 5),
#  ('Male Jaguar', 4),
#  ('Male Lamborghini', 4),
#  ('Male Plymouth', 4),
#  ('Male Porsche', 4),
#  ('Male Aston Martin', 3),
#  ('Male Bentley', 3),
#  ('Male Chrysler', 3),
#  ('Male Isuzu', 3),
#  ('Male Land Rover', 3),
#  ('Male Maserati', 3),
#  ('Male Saturn', 3),
#  ('Male Geo', 2),
#  ('Male Maybach', 2),
#  ('Male Panoz', 2),
#  ('Male Suzuki', 2),
#  ('Male Aptera', 1),
#  ('Male Austin', 1),
#  ('Male Corbin', 1),
#  ('Male Daewoo', 1),
#  ('Male Eagle', 1),
#  ('Male Jensen', 1),
#  ('Male Rolls-Royce', 1),
#  ('Male Scion', 1),
#  ('Male Smart', 1),
#  ('Female Chevrolet', 42),
#  ('Female Ford', 42),
#  ('Female GMC', 22),
#  ('Female Mitsubishi', 22),
#  ('Female Toyota', 20),
#  ('Female Dodge', 17),
#  ('Female Mercedes-Benz', 17),
#  ('Female Lexus', 15),
#  ('Female Pontiac', 14),
#  ('Female Audi', 13),
#  ('Female Mazda', 13),
#  ('Female Volvo', 13),
#  ('Female BMW', 12),
#  ('Female Nissan', 12),
#  ('Female Suzuki', 12),
#  ('Female Buick', 11),
#  ('Female Volkswagen', 10),
#  ('Female Acura', 9),
#  ('Female Infiniti', 9),
#  ('Female Kia', 9),
#  ('Female Honda', 8),
#  ('Female Land Rover', 8),
#  ('Female Oldsmobile', 8),
#  ('Female Cadillac', 6),
#  ('Female Chrysler', 6),
#  ('Female Subaru', 6),
#  ('Female Jeep', 5),
#  ('Female Lotus', 5),
#  ('Female Mercury', 5),
#  ('Female Bentley', 4),
#  ('Female Hyundai', 4),
#  ('Female Lincoln', 4),
#  ('Female Isuzu', 3),
#  ('Female Jaguar', 3),
#  ('Female Plymouth', 3),
#  ('Female Porsche', 3),
#  ('Female Saab', 3),
#  ('Female Saturn', 3),
#  ('Female Aston Martin', 2),
#  ('Female Lamborghini', 2),
#  ('Female Scion', 2),
#  ('Female Austin', 1),
#  ('Female Bugatti', 1),
#  ('Female Eagle', 1),
#  ('Female Geo', 1),
#  ('Female Morgan', 1),
#  ('Female Panoz', 1),
#  ('Female Rolls-Royce', 1)]

# %%
# Out:
# [('Male Ford', 40),
#  ('Male Chevrolet', 30),
#  ('Male GMC', 28),
#  ('Male Mitsubishi', 28),
#  ('Male Dodge', 22),
#  ('Male Toyota', 21),
#  ('Male Mercedes-Benz', 19),
#  ('Male Volkswagen', 16),
#  ('Male Audi', 14),
#  ('Male Buick', 13),
#  ('Male Mazda', 13),
#  ('Male BMW', 12),
#  ('Male Mercury', 11),
#  ('Male Pontiac', 11),
#  ('Male Volvo', 10),
#  ('Male Cadillac', 9),
#  ('Male Honda', 9),
#  ('Male Hyundai', 8),
#  ('Male Saab', 8),
#  ('Male Subaru', 8),
#  ('Male Acura', 7),
#  ('Male Infiniti', 7),
#  ('Male Jeep', 7),
#  ('Male Lexus', 6),
#  ('Male Nissan', 6),
#  ('Male Kia', 5),
#  ('Male Lincoln', 5),
#  ('Male Lotus', 5),
#  ('Male Oldsmobile', 5),
#  ('Male Jaguar', 4),
#  ('Male Lamborghini', 4),
#  ('Male Plymouth', 4),
#  ('Male Porsche', 4),
#  ('Male Aston Martin', 3),
#  ('Male Bentley', 3),
#  ('Male Chrysler', 3),
#  ('Male Isuzu', 3),
#  ('Male Land Rover', 3),
#  ('Male Maserati', 3),
#  ('Male Saturn', 3),
#  ('Male Geo', 2),
#  ('Male Maybach', 2),
#  ('Male Panoz', 2),
#  ('Male Suzuki', 2),
#  ('Male Aptera', 1),
#  ('Male Austin', 1),
#  ('Male Corbin', 1),
#  ('Male Daewoo', 1),
#  ('Male Eagle', 1),
#  ('Male Jensen', 1),
#  ('Male Rolls-Royce', 1),
#  ('Male Scion', 1),
#  ('Male Smart', 1),
#  ('Female Chevrolet', 42),
#  ('Female Ford', 42),
#  ('Female GMC', 22),
#  ('Female Mitsubishi', 22),
#  ('Female Toyota', 20),
#  ('Female Dodge', 17),
#  ('Female Mercedes-Benz', 17),
#  ('Female Lexus', 15),
#  ('Female Pontiac', 14),
#  ('Female Audi', 13),
#  ('Female Mazda', 13),
#  ('Female Volvo', 13),
#  ('Female BMW', 12),
#  ('Female Nissan', 12),
#  ('Female Suzuki', 12),
#  ('Female Buick', 11),
#  ('Female Volkswagen', 10),
#  ('Female Acura', 9),
#  ('Female Infiniti', 9),
#  ('Female Kia', 9),
#  ('Female Honda', 8),
#  ('Female Land Rover', 8),
#  ('Female Oldsmobile', 8),
#  ('Female Cadillac', 6),
#  ('Female Chrysler', 6),
#  ('Female Subaru', 6),
#  ('Female Jeep', 5),
#  ('Female Lotus', 5),
#  ('Female Mercury', 5),
#  ('Female Bentley', 4),
#  ('Female Hyundai', 4),
#  ('Female Lincoln', 4),
#  ('Female Isuzu', 3),
#  ('Female Jaguar', 3),
#  ('Female Plymouth', 3),
#  ('Female Porsche', 3),
#  ('Female Saab', 3),
#  ('Female Saturn', 3),
#  ('Female Aston Martin', 2),
#  ('Female Lamborghini', 2),
#  ('Female Scion', 2),
#  ('Female Austin', 1),
#  ('Female Bugatti', 1),
#  ('Female Eagle', 1),
#  ('Female Geo', 1),
#  ('Female Morgan', 1),
#  ('Female Panoz', 1),
#  ('Female Rolls-Royce', 1)]

# %%
dict(sorted(defau.items(), key = lambda x: x[1], reverse=True))
# Out:
# {'Female Chevrolet': 42,
#  'Female Ford': 42,
#  'Male Ford': 40,
#  'Male Chevrolet': 30,
#  'Male GMC': 28,
#  'Male Mitsubishi': 28,
#  'Female GMC': 22,
#  'Male Dodge': 22,
#  'Female Mitsubishi': 22,
#  'Male Toyota': 21,
#  'Female Toyota': 20,
#  'Male Mercedes-Benz': 19,
#  'Female Mercedes-Benz': 17,
#  'Female Dodge': 17,
#  'Male Volkswagen': 16,
#  'Female Lexus': 15,
#  'Male Audi': 14,
#  'Female Pontiac': 14,
#  'Male Buick': 13,
#  'Female Volvo': 13,
#  'Female Audi': 13,
#  'Male Mazda': 13,
#  'Female Mazda': 13,
#  'Female BMW': 12,
#  'Female Nissan': 12,
#  'Female Suzuki': 12,
#  'Male BMW': 12,
#  'Male Pontiac': 11,
#  'Male Mercury': 11,
#  'Female Buick': 11,
#  'Male Volvo': 10,
#  'Female Volkswagen': 10,
#  'Female Acura': 9,
#  'Male Cadillac': 9,
#  'Female Kia': 9,
#  'Male Honda': 9,
#  'Female Infiniti': 9,
#  'Female Land Rover': 8,
#  'Male Subaru': 8,
#  'Female Honda': 8,
#  'Male Hyundai': 8,
#  'Male Saab': 8,
#  'Female Oldsmobile': 8,
#  'Male Acura': 7,
#  'Male Infiniti': 7,
#  'Male Jeep': 7,
#  'Female Chrysler': 6,
#  'Female Cadillac': 6,
#  'Female Subaru': 6,
#  'Male Lexus': 6,
#  'Male Nissan': 6,
#  'Male Oldsmobile': 5,
#  'Female Jeep': 5,
#  'Male Lincoln': 5,
#  'Female Mercury': 5,
#  'Male Kia': 5,
#  'Female Lotus': 5,
#  'Male Lotus': 5,
#  'Male Jaguar': 4,
#  'Male Plymouth': 4,
#  'Female Bentley': 4,
#  'Male Porsche': 4,
#  'Female Hyundai': 4,
#  'Female Lincoln': 4,
#  'Male Lamborghini': 4,
#  'Female Isuzu': 3,
#  'Male Aston Martin': 3,
#  'Female Plymouth': 3,
#  'Male Isuzu': 3,
#  'Male Maserati': 3,
#  'Female Saturn': 3,
#  'Male Chrysler': 3,
#  'Male Saturn': 3,
#  'Male Bentley': 3,
#  'Female Porsche': 3,
#  'Male Land Rover': 3,
#  'Female Saab': 3,
#  'Female Jaguar': 3,
#  'Female Scion': 2,
#  'Male Maybach': 2,
#  'Female Aston Martin': 2,
#  'Female Lamborghini': 2,
#  'Male Panoz': 2,
#  'Male Geo': 2,
#  'Male Suzuki': 2,
#  'Female Bugatti': 1,
#  'Female Rolls-Royce': 1,
#  'Male Scion': 1,
#  'Male Jensen': 1,
#  'Male Smart': 1,
#  'Female Eagle': 1,
#  'Female Geo': 1,
#  'Male Rolls-Royce': 1,
#  'Male Corbin': 1,
#  'Male Daewoo': 1,
#  'Female Morgan': 1,
#  'Female Austin': 1,
#  'Male Aptera': 1,
#  'Male Eagle': 1,
#  'Female Panoz': 1,
#  'Male Austin': 1}
